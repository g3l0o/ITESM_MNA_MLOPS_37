# %%
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import sys
import os
# Añadir la ruta del módulo 'refactoring' al sys.path
sys.path.append(os.path.abspath("../refactoring"))
# Ahora puedes importar tus módulos
from v1 import preproccesing, transformation
from v1.pipelineObj import Pipeline

# %%
pipe = Pipeline()
pipe.load_data('../data/raw/pricerunner_aggregate.csv')

# %%
pipe.df.head()
# Out:
#    Product ID                                      Product Title  \
# 0           1                    apple iphone 8 plus 64gb silver
# 1           2                apple iphone 8 plus 64 gb spacegrau
# 2           3  apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...
# 3           4                apple iphone 8 plus 64gb space grey
# 4           5  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...
#
#     Merchant ID   Cluster ID             Cluster Label   Category ID  \
# 0             1            1  Apple iPhone 8 Plus 64GB          2612
# 1             2            1  Apple iPhone 8 Plus 64GB          2612
# 2             3            1  Apple iPhone 8 Plus 64GB          2612
# 3             4            1  Apple iPhone 8 Plus 64GB          2612
# 4             5            1  Apple iPhone 8 Plus 64GB          2612
#
#    Category Label
# 0   Mobile Phones
# 1   Mobile Phones
# 2   Mobile Phones
# 3   Mobile Phones
# 4   Mobile Phones

# %%
pipe.preprocess_data()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/enriquevazquez/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pipe.df.head()
# Out:
#    Category ID Category Label  \
# 0            0  Mobile Phones
# 1            0  Mobile Phones
# 2            0  Mobile Phones
# 3            0  Mobile Phones
# 4            0  Mobile Phones
#
#                                                words
# 0                  [apple, iphone, plus, gb, silver]
# 1               [apple, iphone, plus, gb, spacegrau]
# 2  [apple, mq, iphone, plus, gb, mp, sim, free, s...
# 3             [apple, iphone, plus, gb, space, grey]
# 4  [apple, iphone, plus, gold, gb, unlocked, sim,...

# %%
pipe.transform_data()

# %%
df = pd.read_csv('../data/raw/pricerunner_aggregate.csv')

# %%
df.head()
# Out:
#    Product ID                                      Product Title  \
# 0           1                    apple iphone 8 plus 64gb silver
# 1           2                apple iphone 8 plus 64 gb spacegrau
# 2           3  apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...
# 3           4                apple iphone 8 plus 64gb space grey
# 4           5  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...
#
#     Merchant ID   Cluster ID             Cluster Label   Category ID  \
# 0             1            1  Apple iPhone 8 Plus 64GB          2612
# 1             2            1  Apple iPhone 8 Plus 64GB          2612
# 2             3            1  Apple iPhone 8 Plus 64GB          2612
# 3             4            1  Apple iPhone 8 Plus 64GB          2612
# 4             5            1  Apple iPhone 8 Plus 64GB          2612
#
#    Category Label
# 0   Mobile Phones
# 1   Mobile Phones
# 2   Mobile Phones
# 3   Mobile Phones
# 4   Mobile Phones

# %%
df = preproccesing.preprocces(df)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/enriquevazquez/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.head()
# Out:
#    Category ID Category Label  \
# 0            0  Mobile Phones
# 1            0  Mobile Phones
# 2            0  Mobile Phones
# 3            0  Mobile Phones
# 4            0  Mobile Phones
#
#                                                words
# 0                  [apple, iphone, plus, gb, silver]
# 1               [apple, iphone, plus, gb, spacegrau]
# 2  [apple, mq, iphone, plus, gb, mp, sim, free, s...
# 3             [apple, iphone, plus, gb, space, grey]
# 4  [apple, iphone, plus, gold, gb, unlocked, sim,...

# %%
train_vocab, test_vocab,y_train,y_test = transformation.obtain_vocabs(df,0.20,2)
train_embedds = transformation.embedd_sentences(train_vocab)
test_embedds = transformation.embedd_sentences(test_vocab)

# %%
transformation.wordClouds(train_vocab,y_train)

# %%
kmeans = KMeans(n_clusters=10,random_state=2)
kmeans.fit(X=train_embedds)
# Out:
# /opt/anaconda3/envs/MLOps/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=10, random_state=2)

# %%
predicts = kmeans.predict(X = train_embedds)

# %%
acc = accuracy_score(y_train,predicts)
acc
# Out:
# 0.14928490512602663

# %%
cm = confusion_matrix(y_train,predicts)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,)
disp.plot()
plt.show()
